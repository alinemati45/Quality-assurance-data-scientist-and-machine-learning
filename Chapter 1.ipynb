# %% [markdown]
# Ch1.

# %% [markdown]
# # Import libraries

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"


import warnings
warnings.filterwarnings("ignore")
seed = 12345

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-1.5.2-cp38-cp38-macosx_11_0_arm64.whl (10.7 MB)
# Collecting numpy>=1.20.3
#   Downloading numpy-1.24.1-cp38-cp38-macosx_11_0_arm64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/parsanemati/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 24.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /Users/parsanemati/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.24.1 pandas-1.5.2 pytz-2022.7.1

# %%
import pandas as pd
# Read dataset from github
url = "https://raw.githubusercontent.com/alinemati45/Quality-assurance-data-scientist-and-machine-learning/main/data/creditcard.csv.zip"

df = pd.read_csv(url)
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# V12     284807.0 -1.247012e-15      0.999201  -18.683715     -0.405571
# V13     284807.0  8.190001e-16      0.995274   -5.791881     -0.648539
# V14     284807.0  1.207294e-15      0.958596  -19.214325     -0.425574
# V15     284807.0  4.887456e-15      0.915316   -4.498945     -0.582884
# V16     284807.0  1.437716e-15      0.876253  -14.129855     -0.468037
# V17     284807.0 -3.772171e-16      0.849337  -25.162799     -0.483748
# V18     284807.0  9.564149e-16      0.838176   -9.498746     -0.498850
# V19     284807.0  1.039917e-15      0.814041   -7.213527     -0.456299
# V20     284807.0  6.406204e-16      0.770925  -54.497720     -0.211721
# V21     284807.0  1.654067e-16      0.734524  -34.830382     -0.228395
# V22     284807.0 -3.568593e-16      0.725702  -10.933144     -0.542350
# V23     284807.0  2.578648e-16      0.624460  -44.807735     -0.161846
# V24     284807.0  4.473266e-15      0.605647   -2.836627     -0.354586
# V25     284807.0  5.340915e-16      0.521278  -10.295397     -0.317145
# V26     284807.0  1.683437e-15      0.482227   -2.604551     -0.326984
# V27     284807.0 -3.660091e-16      0.403632  -22.565679     -0.070840
# V28     284807.0 -1.227390e-16      0.330083  -15.430084     -0.052960
# Amount  284807.0  8.834962e+01    250.120109    0.000000      5.600000
# Class   284807.0  1.727486e-03      0.041527    0.000000      0.000000
#
#                  50%            75%            max
# Time    84692.000000  139320.500000  172792.000000
# V1          0.018109       1.315642       2.454930
# V2          0.065486       0.803724      22.057729
# V3          0.179846       1.027196       9.382558
# V4         -0.019847       0.743341      16.875344
# V5         -0.054336       0.611926      34.801666
# V6         -0.274187       0.398565      73.301626
# V7          0.040103       0.570436     120.589494
# V8          0.022358       0.327346      20.007208
# V9         -0.051429       0.597139      15.594995
# V10        -0.092917       0.453923      23.745136
# V11        -0.032757       0.739593      12.018913
# V12         0.140033       0.618238       7.848392
# V13        -0.013568       0.662505       7.126883
# V14         0.050601       0.493150      10.526766
# V15         0.048072       0.648821       8.877742
# V16         0.066413       0.523296      17.315112
# V17        -0.065676       0.399675       9.253526
# V18        -0.003636       0.500807       5.041069
# V19         0.003735       0.458949       5.591971
# V20        -0.062481       0.133041      39.420904
# V21        -0.029450       0.186377      27.202839
# V22         0.006782       0.528554      10.503090
# V23        -0.011193       0.147642      22.528412
# V24         0.040976       0.439527       4.584549
# V25         0.016594       0.350716       7.519589
# V26        -0.052139       0.240952       3.517346
# V27         0.001342       0.091045      31.612198
# V28         0.011244       0.078280      33.847808
# Amount     22.000000      77.165000   25691.160000
# Class       0.000000       0.000000       1.000000

# %%
print(list(df))
# Out:
# ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']

# %%
# !pip install seaborn matplotlib
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 4.6 MB/s eta 0:00:00a 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.6.3-cp38-cp38-macosx_11_0_arm64.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 48.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/parsanemati/miniconda3/envs/Quality_assurance/lib/python3.8/site-packages (from seaborn) (1.24.1)
# Requirement already satisfied: pandas>=0.25 in /Users/parsanemati/miniconda3/envs/Quality_assurance/lib/python3.8/site-packages (from seaborn) (1.5.2)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp38-cp38-macosx_11_0_arm64.whl (63 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/parsanemati/.local/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-macosx_11_0_arm64.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.6/229.6 kB 11.5 MB/s eta 0:00:00
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.4.0-cp38-cp38-macosx_11_0_arm64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 54.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/parsanemati/.local/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/parsanemati/.local/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/parsanemati/miniconda3/envs/Quality_assurance/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /Users/parsanemati/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.6.3 pillow-9.4.0 seaborn-0.12.2

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.12.0-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 60.4 MB/s eta 0:00:00a 0:00:01
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.1.0-py3-none-any.whl (23 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.12.0 tenacity-8.1.0

# %%
import numpy as np
n=len(df)
count_class_0=len(df[df['Class']==0])
count_class_1=len(df[df['Class']==1])

print("Dataset percent for class 0 : ",np.round(count_class_0*100/n , 3) , "%  , Dataset count for class 0 : " , count_class_0)
print("Dataset percent for class 1 : ",np.round(count_class_1*100/n ,3) , "%  , Dataset count for class 0 : "  , count_class_1)
# Out:
# Dataset percent for class 0 :  99.827 %  , Dataset count for class 0 :  284315
# Dataset percent for class 1 :  0.173 %  , Dataset count for class 0 :  492

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /Users/parsanemati/miniconda3/envs/Quality_assurance/lib/python3.8/site-packages (1.24.1)

# %%
###########################################################################
###########################################################################
###                                                                     ###
###        COUNT OF TARGET: 0 =  , 1 =          ###
###                                                                     ###
###########################################################################
###########################################################################


import plotly.express as px
fig = px.histogram(df, x="Class",color="Class" , width=400, height=400)
fig.show()
